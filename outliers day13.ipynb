# %% [markdown]
# # Outliers
# - Outliers are data points that are very different from most of the values in a dataset
# - They can happen because of data entry mistakes, measurement errors, or real world  events
# # ![Outliers.webp](attachment:b9874d56-aa8f-40e3-8386-8396210b366e.webp)

# %%
1)IQR Method:-
formula:
IQR=Q3-Q1

# %% [markdown]
# # ![WhatsApp Image 2025-12-20 at 1.39.02 PM.jpeg](attachment:804f8dc0-c86d-4a69-9632-f5170f5ea61b.jpeg)

# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.1 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.1 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.7 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.1 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.1 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.4 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.1 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.1 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 1.6 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.1 MB 1.5 MB/s eta 0:00:03
# ...

# %%
data=pd.DataFrame({
    "Marks":[23,25,12,24,41,32,21]
})

# %%
data
# Out:
#    Marks
# 0     23
# 1     25
# 2     12
# 3     24
# 4     41
# 5     32
# 6     21

# %%
data.describe()
# Out:
#            Marks
# count   7.000000
# mean   25.428571
# std     9.071147
# min    12.000000
# 25%    22.000000
# 50%    24.000000
# 75%    28.500000
# max    41.000000

# %% [markdown]
# # IQR Method

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR = Q3-Q1
LB=Q1-1.5*IQR
UB=Q3+1.*IQR
outliers=data[(data<(LB)) | (data>(UB))]

# %%
outliers
# Out:
#    Marks
# 0    NaN
# 1    NaN
# 2   12.0
# 3    NaN
# 4   41.0
# 5    NaN
# 6    NaN

# %% [markdown]
# # Z-Score

# %% [raw]
# - Z score is a Statistical technique that detects outliers based on how far a data point is from the mean, measured in terms of standard deviations. It assumes the data follows a normal distribution.
# - A point with a very high or low Z-Score (typically |z| >3) is flagged as an outlier because it lies in the extreme tails of the distribution.
# Formula:-
# z=(X- mean)/ SD

# %% [markdown]
# # ![WhatsApp Image 2025-12-20 at 1.51.30 PM.jpeg](attachment:36a79db4-be60-4902-9804-9125af0f4dc5.jpeg)

# %%
sample=pd.DataFrame({
    "ages":[10,11,12,13,14,15,50]
})

# %%
sample
# Out:
#    ages
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    50

# %%
stats.zscore(sample["ages"])
# Out:
# array([-0.59446434, -0.51880524, -0.44314614, -0.36748705, -0.29182795,
#        -0.21616885,  2.43189957])

# %%
z_scores=np.abs(stats.zscore(sample["ages"]))

# %%
z_scores
# Out:
# array([0.59446434, 0.51880524, 0.44314614, 0.36748705, 0.29182795,
#        0.21616885, 2.43189957])

# %%
outliers=sample[z_scores>2]
outliers
# Out:
#    ages
# 6    50

# %%
plt.scatter(range(len(sample)),sample["ages"])
plt.xlabel("Index")
plt.ylabel("Ages")
plt.title("Scatter plot showing Outlier")
plt.show()

# %%
plt.hist(sample["ages"],10)
plt.xlabel("Ages")
plt.ylabel("Frequency")
plt.title("Histogram showing Outlier Effect")
plt.show()
